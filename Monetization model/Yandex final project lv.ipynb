# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание" data-toc-modified-id="Описание-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание</a></span></li><li><span><a href="#Работа-с-данными" data-toc-modified-id="Работа-с-данными-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Работа с данными</a></span><ul class="toc-item"><li><span><a href="#Обзор-датасетов" data-toc-modified-id="Обзор-датасетов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обзор датасетов</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-по-каналам-привлечения" data-toc-modified-id="Распределение-по-каналам-привлечения-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Распределение по каналам привлечения</a></span></li><li><span><a href="#Распределение-затрат-на-привлечение" data-toc-modified-id="Распределение-затрат-на-привлечение-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Распределение затрат на привлечение</a></span></li><li><span><a href="#Распределение-пользователей-по-событиям" data-toc-modified-id="Распределение-пользователей-по-событиям-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Распределение пользователей по событиям</a></span></li><li><span><a href="#Количество-времени-в-игре" data-toc-modified-id="Количество-времени-в-игре-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Количество времени в игре</a></span></li><li><span><a href="#Исследование-пользовательских-стратегий" data-toc-modified-id="Исследование-пользовательских-стратегий-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Исследование пользовательских стратегий</a></span></li></ul></li><li><span><a href="#👨‍🚒--Комментарий-тимлида" data-toc-modified-id="👨‍🚒--Комментарий-тимлида-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>👨‍🚒  Комментарий тимлида</a></span></li></ul></li><li><span><a href="#Расчет-бизнес-показателей" data-toc-modified-id="Расчет-бизнес-показателей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчет бизнес-показателей</a></span><ul class="toc-item"><li><span><a href="#Расчет-CAC,-LTV,-ROI" data-toc-modified-id="Расчет-CAC,-LTV,-ROI-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Расчет CAC, LTV, ROI</a></span></li><li><span><a href="#👨‍🚒--Комментарий-тимлида" data-toc-modified-id="👨‍🚒--Комментарий-тимлида-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>👨‍🚒  Комментарий тимлида</a></span></li><li><span><a href="#Расчет-метрик-общей-группы-пользователей" data-toc-modified-id="Расчет-метрик-общей-группы-пользователей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Расчет метрик общей группы пользователей</a></span></li><li><span><a href="#Расчет-метрик-в-разрезе-каналов-привлечения" data-toc-modified-id="Расчет-метрик-в-разрезе-каналов-привлечения-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Расчет метрик в разрезе каналов привлечения</a></span></li><li><span><a href="#Расчет-метрик-для-категорий-пользователей-по-способу-прохождения-уровня" data-toc-modified-id="Расчет-метрик-для-категорий-пользователей-по-способу-прохождения-уровня-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Расчет метрик для категорий пользователей по способу прохождения уровня</a></span></li><li><span><a href="#Сценарий-с-показом-рекламы-при-завершении-уровня" data-toc-modified-id="Сценарий-с-показом-рекламы-при-завершении-уровня-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Сценарий с показом рекламы при завершении уровня</a></span></li><li><span><a href="#Сценарий-с-показом-рекламы-при-строительстве-одного-из-типов-зданий" data-toc-modified-id="Сценарий-с-показом-рекламы-при-строительстве-одного-из-типов-зданий-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Сценарий с показом рекламы при строительстве одного из типов зданий</a></span></li><li><span><a href="#Сценарий-с-показом-рекламы-со-второго-дня" data-toc-modified-id="Сценарий-с-показом-рекламы-со-второго-дня-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Сценарий с показом рекламы со второго дня</a></span></li><li><span><a href="#Сценарий-с-показом-рекламы-по-прошествии-определенного-количества-построек" data-toc-modified-id="Сценарий-с-показом-рекламы-по-прошествии-определенного-количества-построек-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Сценарий с показом рекламы по прошествии определенного количества построек</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-о-различии-времени-прохождения-первого-уровня" data-toc-modified-id="Гипотеза-о-различии-времени-прохождения-первого-уровня-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Гипотеза о различии времени прохождения первого уровня</a></span></li><li><span><a href="#Гипотеза-о-различии-доли-прибыли,-приносимой-игроками-из-разных-каналов" data-toc-modified-id="Гипотеза-о-различии-доли-прибыли,-приносимой-игроками-из-разных-каналов-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Гипотеза о различии доли прибыли, приносимой игроками из разных каналов</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Формирование модели монетизации игрового приложения "Космические братья"

# %% [markdown]
# 1. [**Описание**](#description)
#
#
# 2. [**Работа с данными**](#workwithdata)
#
#     2.1 [*Обзор датасета*](#datasetrewiev)
#
#     2.2 [*Исследовательский анализ данных*](#EDA)
#
#
# 3. [**Расчет бизнес-показателей**](#metrics)
#
#
# 4. [**Проверка гипотез**](#hyp)

# %% [markdown]
# ## Описание
# <a id = 'description'></a>
#
# Заказчиком проекта выступает команда мобильной игры "Космические братья". Интересы заказчика представляет продакт-менеджер. Команда игры планирует запустить монетизацию. Предполагается показ рекламы пользователям на экране выбора постройки. Заказчику необходима модель монетизации, которая обеспечит рентабельность.
#
#     Для составления модели предполагается выполнить следующие задачи:
#
#         - Провести подготовительную работу с данными (обзор и предобработка);
#
#         - Выделить факторы, которые могли бы повлиять на монетизацию;
#
#         - Провести расчет маркетинговых метрик;
#
#         - Сформулировать и проверить статистические гипотезы;
#
#         - Сделать выводы и подготовить рекомендации.

# %%
import pandas as pd
import re as re
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
import datetime
from scipy import stats as st
import math as mt
from cycler import cycler

# %% [markdown]
# **_Блок с формулами_**

# %%
''' Функция plot_func группирует датафрейм (df) по необходимому для расчета столбцу(group_column),
        примения аггрегирующую функцию (aggfunc). На вход функции подается заголовок графика (figure_name),
        а также названия осей x и у соответственно (xlabel_name, ylabel_name) '''

def plot_func(df, figure_name, xlabel_name,ylabel_name,
             agg_func, group_column):
    new_df = eval('df.groupby(group_column).{}()'.format(agg_func))
    new_col_name = ''
    for x in new_df.columns:
        new_col_name = x
    new_df = new_df.sort_values(by=new_col_name)
    colors = ['aquamarine', 'violet', 'wheat', 'cornflowerblue']
    xticks = [re.sub('_+',' ',x).capitalize() for x in new_df.index]
    plt.figure(figsize=(8,8))
    plt.bar(new_df[new_col_name].index, new_df[new_col_name], color=colors,ec='black'
           ,alpha=0.5)
    plt.title(figure_name)
    plt.xticks(new_df.index,xticks)
    plt.grid(color='black', alpha = 0.1, axis = 'y', linestyle = ':')
    plt.tick_params(direction='inout')
    plt.xlabel(xlabel_name)
    plt.ylabel(ylabel_name)
    plt.yticks(np.arange (0, round(new_df[new_col_name].max()/500 + 1.1)*500, 500))
    sns.despine()
    plt.show()
    

''' Функция hist_func принимает на вход столбец датафрейма (series), по которому необходимо построить распределение.
        На вход функции подается заголовок графика (figure_name),а также названия осей x и у 
        соответственно (xlabel_name, ylabel_name) '''

def hist_func(series, figure_name, xlabel_name,ylabel_name):
    plt.figure(figsize=(8,8))
    plt.hist(series, histtype='bar', ec='black', bins=50, color='aquamarine',alpha=0.5)
    plt.grid(color='black', alpha = 0.1, axis = 'y', linestyle = ':')
    sns.despine()
    plt.ylabel(ylabel_name)
    plt.xlabel(xlabel_name)
    plt.title(figure_name)
    plt.tick_params(direction='inout')
    plt.show()
    
    
''' Функция принимает на вход датафрейм, содержащий информацию о действиях пользователей и возвращает
        таблицу с пользовательскими профилями '''

def get_profiles(sessions):
    profiles = (
        sessions.sort_values(by=['user_id', 'event_datetime'])
        .groupby('user_id')
        .agg({'date': 'first', 'source': 'first', 'category':'first'})
        .rename(columns={'date': 'first_action'})
        .reset_index()  # возвращаем user_id из индекса
    )
    profiles['month'] = profiles['first_action'].astype('datetime64[M]')

    return profiles


''' Функция принимает на вход два датафрейма. С таблицей профилей пользователей и с таблицей, содержащей информацию 
о прибыльном действии пользователя. На выходе выдаются таблицы LTV и ROI'''
def get_ltv(
    profiles,
    purchases,
    dimensions=[]
):

    result_raw = profiles
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'date', 'click_cost','acquisition_cost']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['date'] - result_raw['first_action']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='click_cost', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        result['cohort_size'] = cohort_sizes

        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)


        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['first_action']
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )


''' Функция vis_ltv строит линейные графики ltv когорт пользователей'''

def vis_ltv(df, title):
    fig,ax = plt.subplots()
    df.plot(figsize=(10, 5), xticks=list(report.columns.values), ax=ax, linewidth=2)
    plt.title(title)
    plt.ylabel('LTV, $')
    plt.xlabel('Лайфтайм')
    colormap = plt.cm.gist_rainbow
    colors = [colormap(i) for i in np.linspace(0, 1,len(ax.lines))]
    for i,j in enumerate(ax.lines):
        j.set_color(colors[i])
    plt.grid(color='black', linestyle='dotted', alpha = 0.5)
    plt.tick_params(direction='inout')
    sns.despine()
    plt.legend()
    plt.show()
    
    
''' Функция vis_roi строит линейные графики ROMI '''  

def vis_roi(df, title):
    fig,ax = plt.subplots()
    df.T.plot(figsize=(10, 5), xticks=list(df.columns.values), ax=ax, linewidth=2)
    plt.title(title)
    plt.ylabel('ROMI')
    plt.xlabel('Лайфтайм')
    colormap = plt.cm.gist_rainbow
    colors = [colormap(i) for i in np.linspace(0, 1,len(ax.lines))]
    for i,j in enumerate(ax.lines):
        j.set_color(colors[i])
    plt.grid(color='black', linestyle='dotted', alpha = 0.5)
    plt.tick_params(direction='inout')
    sns.despine()
    plt.axhline(y=1, color='black', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Работа с данными
# <a id = "workwithdata"></a>

# %% [markdown]
# ### Обзор датасетов
# <a id = "datasetrewiev"></a>

# %%
# Откроем файлы с датасетами 
ad_costs = pd.read_csv('/datasets/ad_costs.csv')
game_actions = pd.read_csv('/datasets/game_actions.csv')
user_source = pd.read_csv('/datasets/user_source.csv')

# %%
# Посмотрим на характеристики датасетов и их содержание
display(ad_costs.head(20))
ad_costs.info()

display(game_actions.head(20))
game_actions.info()

display(user_source.head(20))
user_source.info()
# Out:
#                    source         day        cost
# 0            facebook_ads  2020-05-03  935.882786
# 1            facebook_ads  2020-05-04  548.354480
# 2            facebook_ads  2020-05-05  260.185754
# 3            facebook_ads  2020-05-06  177.982200
# 4            facebook_ads  2020-05-07  111.766796
# 5            facebook_ads  2020-05-08   68.009276
# 6            facebook_ads  2020-05-09   38.723350
# 7   instagram_new_adverts  2020-05-03  943.204717
# 8   instagram_new_adverts  2020-05-04  502.925451
# 9   instagram_new_adverts  2020-05-05  313.970984
# 10  instagram_new_adverts  2020-05-06  173.071145
# 11  instagram_new_adverts  2020-05-07  109.915254
# 12  instagram_new_adverts  2020-05-08   71.578739
# 13  instagram_new_adverts  2020-05-09   46.775400
# 14          yandex_direct  2020-05-03  969.139394
# 15          yandex_direct  2020-05-04  554.651494
# 16          yandex_direct  2020-05-05  308.232990
# 17          yandex_direct  2020-05-06  180.917099
# ...

# %% [markdown]
# Столбцы day в ad_costs и event_datetime в game_actions имеют тип object. Преобразуем их в тип datetime.

# %%
ad_costs['day'] = pd.to_datetime(ad_costs['day'])
game_actions['event_datetime'] = pd.to_datetime(game_actions['event_datetime'])

# %% [markdown]
# Датасет с событиями содержит пропуски в столбцах project_type и building_type. Посмотрим какие значения присустствуют в обоих столбцах.

# %%
print('Значения столбца project_type:')
for x in game_actions['project_type'].unique(): print(x)

print('\nЗначения столбца building_type:')
for x in game_actions['building_type'].unique(): print(x)
# Out:
# Значения столбца project_type:
# nan
# satellite_orbital_assembly
#
# Значения столбца building_type:
# assembly_shop
# spaceport
# nan
# research_center

# %% [markdown]
# Согласно документации может быть 2 пути завершения первого уровня: реализация проекта и победа над врагом. Если уровень пройден, а в project_type отсутствует значение, значит пользователь одержал победу над врагом. В остальных случаях первый уровень не пройден.

# %%
# Проверим количество прошедших первый уровень игроков
game_actions.query('event == "finished_stage_1"').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5817 entries, 6659 to 135639
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_datetime  5817 non-null   datetime64[ns]
#  1   event           5817 non-null   object
#  2   building_type   0 non-null      object
#  3   user_id         5817 non-null   object
#  4   project_type    0 non-null      object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 272.7+ KB

# %%
game_actions['event_datetime']
# Out:
# 0        2020-05-04 00:00:01
# 1        2020-05-04 00:00:03
# 2        2020-05-04 00:00:16
# 3        2020-05-04 00:00:16
# 4        2020-05-04 00:00:35
#                  ...
# 135635   2020-06-05 00:08:06
# 135636   2020-06-05 02:25:12
# 135637   2020-06-05 08:57:52
# 135638   2020-06-05 12:12:27
# 135639   2020-06-05 12:32:49
# Name: event_datetime, Length: 135640, dtype: datetime64[ns]

# %%
game_actions.query('event == "project"').info()
game_actions.query('project_type == "satellite_orbital_assembly"').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1866 entries, 47121 to 135630
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_datetime  1866 non-null   datetime64[ns]
#  1   event           1866 non-null   object
#  2   building_type   0 non-null      object
#  3   user_id         1866 non-null   object
#  4   project_type    1866 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 87.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1866 entries, 47121 to 135630
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_datetime  1866 non-null   datetime64[ns]
#  1   event           1866 non-null   object
#  2   building_type   0 non-null      object
#  3   user_id         1866 non-null   object
#  4   project_type    1866 non-null   object
# dtypes: datetime64[ns](1), object(4)
# ...

# %% [markdown]
# Видим, что для данной категории игроков заполнено поле project_type. Предположения оказались верными. Для игроков победивших врагов не указано значение 'project_type'. Все остальные игроки не прошли первый уровень.

# %% [markdown]
# Проверим отсутствующие значения в столбце 'building_type'.

# %%
print(game_actions[game_actions['building_type'].isna()]['event'].unique())
# Out:
# ['finished_stage_1' 'project']

# %% [markdown]
# Видим, что значения отсутствуют для событий не связанных со строительством.
#
# В заполнение пропусков необходимости нет.

# %% [markdown]
# Проверим наличие дубликатов во всех датафреймах

# %%
print('Количество дубликатов в датафрейме ad_costs:',ad_costs.duplicated().sum())
print('Количество дубликатов в датафрейме game_actions:',game_actions.duplicated().sum())
print('Количество дубликатов в датафрейме user_source:',user_source.duplicated().sum())
# Out:
# Количество дубликатов в датафрейме ad_costs: 0
# Количество дубликатов в датафрейме game_actions: 1
# Количество дубликатов в датафрейме user_source: 0

# %% [markdown]
# В датафрейме game_actions найден 1 дубликат.

# %%
game_actions[game_actions.duplicated()]
# Out:
#            event_datetime     event    building_type  \
# 74891 2020-05-10 18:41:56  building  research_center
#
#                                     user_id project_type
# 74891  c9af55d2-b0ae-4bb4-b3d5-f32aa9ac03af          NaN

# %% [markdown]
# Данный дубликат не окажет никакого влияния на массив данных

# %% [markdown]
# В ходе предобработки данных не выявлено критических замечаний. Были найдены пропуски в датафрейме game_actions, находящиеся в столбцах building_type и project_type. В столбце building_type значения отсутствуют для записей с событиями, которые не относятся к строительству. В столбцу project_type содержится информация о типе проекта. Т.к. возможно выполнить только один проект - разработку орбитальной сборки спутников, остальные ячейки остались пустыми. Был найден 1 дубликат в датафрейме game_actions. Заполнения пропусков и удаление дубликатов не требуется.

# %% [markdown]
# ### Исследовательский анализ данных
# <a id = "EDA"></a>

# %% [markdown]
# #### Распределение по каналам привлечения

# %% [markdown]
# Построим график распределения пользователей по каналам привлечения

# %%
plot_func(user_source, 'Распределение привлеченных пользователей по рекламным каналам'
         , 'Источник привлечения', 'Число пользователей', 'count','source')

# %% [markdown]
# Больше всего пользователей пришло из Yandex direct около 4800, далее расположился Instagram new adverts с количеством пользователей в районе 3400, из Facebook ads и Youtube channel reklama поступило примерно одинаковое число пользователей 2600.

# %% [markdown]
# #### Распределение затрат на привлечение

# %%
plot_func(ad_costs, 'Распределение затрат на привлечение'
         , 'Источник привлечения', 'Сумма затрат', 'sum','source')

# %% [markdown]
# Распределение показывает что на рекламу в трех каналах (Facebook ads, Instagram new adverts, Yandex direct) потратили примерно одинаковое количество средств от примерно 2100 до 2300. Реклама в Youtube channel reklama обошлась в 2 раза дешевле, около 1100.
#
# Предварительно видно, что у канала Facebook ads самая высокая стоимость привлечения клиентов, немного ниже у Instagram new adverts. Для каналов Youtube channel reklama и Yandex direct стоимость будет находится примерно на одном уровне и значительно ниже, чем для первых двух источников.

# %% [markdown]
# #### Распределение пользователей по событиям

# %%
plot_func(game_actions[['event','user_id']], 'Распределение игроков по событиям'
         , 'Событие', 'Количество игроков', 'nunique','event')

# %% [markdown]
# Найдем доли игроков в событиях

# %%
game_actions.query('event == "finished_stage_1"').nunique()/game_actions.query('event == "building"').nunique()
# Out:
# event_datetime    0.047794
# event             1.000000
# building_type     0.000000
# user_id           0.428477
# project_type           NaN
# dtype: float64

# %%
game_actions.query('event == "project"').nunique()/game_actions.query('event == "building"').nunique()
# Out:
# event_datetime    0.015355
# event             1.000000
# building_type     0.000000
# user_id           0.137448
# project_type           inf
# dtype: float64

# %% [markdown]
# 42.9 процента игроков завершили 1 уровень, при этом 13.7 выполнили проект

# %% [markdown]
# Из распределения видно, что чуть меньше половины пользователей прошли 1 уровень (около 6000), при этом осуществили проект около 2000.

# %% [markdown]
# #### Количество времени в игре

# %%
game_actions['date'] = game_actions['event_datetime'].dt.date

# %% [markdown]
# Сгруппируем данные для расчета времени, проведенного пользователями в игре

# %%
gametime = game_actions.groupby('user_id').agg({'event_datetime' : ['min','max']})
gametime['lifetime'] = gametime['event_datetime']['max'] - gametime['event_datetime']['min']

# %%
game_actions[['event','user_id']]
# Out:
#                    event                               user_id
# 0               building  55e92310-cb8e-4754-b622-597e124b03de
# 1               building  c07b1c10-f477-44dc-81dc-ec82254b1347
# 2               building  6edd42cc-e753-4ff6-a947-2107cd560710
# 3               building  92c69003-d60a-444a-827f-8cc51bf6bf4c
# 4               building  cdc6bb92-0ccb-4490-9866-ef142f09139d
# ...                  ...                                   ...
# 135635          building  f21d179f-1c4b-437e-b9c6-ab1976907195
# 135636  finished_stage_1  515c1952-99aa-4bca-a7ea-d0449eb5385a
# 135637          building  ed3e7d02-8a96-4be7-9998-e9813ff9c316
# 135638  finished_stage_1  32572adb-900f-4b5d-a453-1eb1e6d88d8b
# 135639  finished_stage_1  f21d179f-1c4b-437e-b9c6-ab1976907195
#
# [135640 rows x 2 columns]

# %%
gametime.head(10)
# Out:
#                                           event_datetime                      \
#                                                      min                 max
# user_id
# 0001f83c-c6ac-4621-b7f0-8a28b283ac30 2020-05-06 01:07:37 2020-05-20 11:26:06
# 00151b4f-ba38-44a8-a650-d7cf130a0105 2020-05-06 03:09:12 2020-05-18 10:46:52
# 001aaea6-3d14-43f1-8ca8-7f48820f17aa 2020-05-05 18:08:52 2020-05-14 09:21:27
# 001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-05 21:02:05 2020-05-12 07:40:47
# 002f508f-67b6-479f-814b-b05f00d4e995 2020-05-05 13:49:58 2020-05-22 02:46:45
# 003b80c6-4164-4157-bb2a-03d0181d39c4 2020-05-04 09:10:22 2020-05-12 15:23:37
# 003ee7e8-6356-4286-a715-62f22a18d2a1 2020-05-05 08:31:04 2020-05-17 21:47:49
# 004074f8-251a-4776-922c-8348dca1a2f6 2020-05-04 01:07:35 2020-05-16 19:57:40
# 00440efd-aa50-4b4b-aae8-ffcd1782729d 2020-05-04 07:20:40 2020-05-09 10:33:13
# 00464e5e-28ed-4be6-bf44-517ef7b3937b 2020-05-04 08:35:29 2020-05-15 16:02:01
#
# ...

# %%
gametime['lifetime'] = gametime['lifetime']/np.timedelta64(1,'h')

# %%
gametime.head(10)
# Out:
#                                           event_datetime                      \
#                                                      min                 max
# user_id
# 0001f83c-c6ac-4621-b7f0-8a28b283ac30 2020-05-06 01:07:37 2020-05-20 11:26:06
# 00151b4f-ba38-44a8-a650-d7cf130a0105 2020-05-06 03:09:12 2020-05-18 10:46:52
# 001aaea6-3d14-43f1-8ca8-7f48820f17aa 2020-05-05 18:08:52 2020-05-14 09:21:27
# 001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-05 21:02:05 2020-05-12 07:40:47
# 002f508f-67b6-479f-814b-b05f00d4e995 2020-05-05 13:49:58 2020-05-22 02:46:45
# 003b80c6-4164-4157-bb2a-03d0181d39c4 2020-05-04 09:10:22 2020-05-12 15:23:37
# 003ee7e8-6356-4286-a715-62f22a18d2a1 2020-05-05 08:31:04 2020-05-17 21:47:49
# 004074f8-251a-4776-922c-8348dca1a2f6 2020-05-04 01:07:35 2020-05-16 19:57:40
# 00440efd-aa50-4b4b-aae8-ffcd1782729d 2020-05-04 07:20:40 2020-05-09 10:33:13
# 00464e5e-28ed-4be6-bf44-517ef7b3937b 2020-05-04 08:35:29 2020-05-15 16:02:01
#
# ...

# %%
hist_func(gametime['lifetime'], 'Распределение игрового времени', 'Значение', 'Количество пользователей')

# %% [markdown]
# Наблюдаем нормальное распределение времени, проведенного пользователями в игре. Среднее значение расположено в районе 250 часов. Получим статистические данные методом describe.

# %%
gametime.describe()
# Out:
#            lifetime
#
# count  13576.000000
# mean     256.218772
# std      104.411303
# min        0.000000
# 25%      184.560764
# 50%      252.514583
# 75%      319.481111
# max      741.981389

# %% [markdown]
# Распределение равномерное, выбросы отсутствуют, на что указывает высокая близость среднего и медианного значений времени.

# %% [markdown]
# #### Исследование пользовательских стратегий

# %% [markdown]
# Для представления о поведении пользователей необходимо изучить данные в разрезе выбора стратегий для перехода на второй уровень, а также выделить категорию пользователей, которые не прошли первый уровень.
#
# Выделим уникальные user_id для трех типов пользователей по способу прохождения и напишем функцию для категоризации.

# %%
project_ids = game_actions[game_actions['event'] == 'project']['user_id'].unique()
finisher_ids = game_actions[game_actions['event'] == 'finished_stage_1']['user_id'].unique()
building_ids = game_actions[game_actions['event'] == 'building']['user_id'].unique()

# %% [markdown]
# Строим таблицу с категорией закончивших первый уровень выполнением проекта

# %%
pju = game_actions.query('event == "project"')
pju['category'] = 'finished by project'
pju
# Out:
# /tmp/ipykernel_569/1836013043.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pju['category'] = 'finished by project'
#             event_datetime    event building_type  \
# 47121  2020-05-08 18:10:25  project           NaN
# 57398  2020-05-09 13:49:11  project           NaN
# 58797  2020-05-09 16:19:33  project           NaN
# 61174  2020-05-09 20:29:01  project           NaN
# 63770  2020-05-10 00:57:47  project           NaN
# ...                    ...      ...           ...
# 135602 2020-06-02 03:04:42  project           NaN
# 135603 2020-06-02 06:21:03  project           NaN
# 135609 2020-06-02 17:17:28  project           NaN
# 135617 2020-06-03 09:46:04  project           NaN
# ...

# %% [markdown]
# Строим таблицу с категорией закончивших первый уровень победой над соперником

# %%
fsu = game_actions.query('event == "finished_stage_1" and user_id not in @project_ids')
fsu['category'] = 'finished by defeating'
fsu
# Out:
# /tmp/ipykernel_569/2543465481.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fsu['category'] = 'finished by defeating'
#             event_datetime             event building_type  \
# 6659   2020-05-04 19:47:29  finished_stage_1           NaN
# 13134  2020-05-05 13:22:09  finished_stage_1           NaN
# 15274  2020-05-05 18:54:37  finished_stage_1           NaN
# 16284  2020-05-05 21:27:29  finished_stage_1           NaN
# 19650  2020-05-06 06:02:22  finished_stage_1           NaN
# ...                    ...               ...           ...
# 135628 2020-06-04 06:44:02  finished_stage_1           NaN
# 135632 2020-06-04 15:50:38  finished_stage_1           NaN
# 135636 2020-06-05 02:25:12  finished_stage_1           NaN
# ...

# %% [markdown]
# Строим таблицу с категорией пользователей не закончивших первый уровень

# %%
nfu = game_actions.query('user_id not in @finisher_ids')
nfu['category'] = 'not finished'
nfu
# Out:
# /tmp/ipykernel_569/503120484.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nfu['category'] = 'not finished'
#             event_datetime     event    building_type  \
# 0      2020-05-04 00:00:01  building    assembly_shop
# 3      2020-05-04 00:00:16  building    assembly_shop
# 5      2020-05-04 00:00:36  building    assembly_shop
# 7      2020-05-04 00:00:38  building    assembly_shop
# 10     2020-05-04 00:01:59  building    assembly_shop
# ...                    ...       ...              ...
# 135594 2020-06-01 16:09:44  building        spaceport
# 135598 2020-06-01 21:30:47  building        spaceport
# 135604 2020-06-02 08:26:32  building  research_center
# 135612 2020-06-02 21:37:17  building        spaceport
# ...

# %%
fst = pd.concat([pju,fsu],axis=0).reset_index(drop=True)
fst
# Out:
#           event_datetime             event building_type  \
# 0    2020-05-08 18:10:25           project           NaN
# 1    2020-05-09 13:49:11           project           NaN
# 2    2020-05-09 16:19:33           project           NaN
# 3    2020-05-09 20:29:01           project           NaN
# 4    2020-05-10 00:57:47           project           NaN
# ...                  ...               ...           ...
# 5812 2020-06-04 06:44:02  finished_stage_1           NaN
# 5813 2020-06-04 15:50:38  finished_stage_1           NaN
# 5814 2020-06-05 02:25:12  finished_stage_1           NaN
# 5815 2020-06-05 12:12:27  finished_stage_1           NaN
# 5816 2020-06-05 12:32:49  finished_stage_1           NaN
#
#                                    user_id                project_type  \
# 0     e3c66498-9d45-4000-9392-f81e6796e7da  satellite_orbital_assembly
# 1     936e7af6-8338-4703-a1df-fc6c3f5b8e34  satellite_orbital_assembly
# ...

# %%
all = pd.concat([fst,nfu],axis=0).reset_index(drop=True)
all
# Out:
#            event_datetime     event    building_type  \
# 0     2020-05-08 18:10:25   project              NaN
# 1     2020-05-09 13:49:11   project              NaN
# 2     2020-05-09 16:19:33   project              NaN
# 3     2020-05-09 20:29:01   project              NaN
# 4     2020-05-10 00:57:47   project              NaN
# ...                   ...       ...              ...
# 72983 2020-06-01 16:09:44  building        spaceport
# 72984 2020-06-01 21:30:47  building        spaceport
# 72985 2020-06-02 08:26:32  building  research_center
# 72986 2020-06-02 21:37:17  building        spaceport
# 72987 2020-06-05 08:57:52  building  research_center
#
#                                     user_id                project_type  \
# 0      e3c66498-9d45-4000-9392-f81e6796e7da  satellite_orbital_assembly
# 1      936e7af6-8338-4703-a1df-fc6c3f5b8e34  satellite_orbital_assembly
# 2      a4491c86-c498-4f74-a56e-65c136d0e9a1  satellite_orbital_assembly
# ...

# %%
ga_with_category = game_actions.merge(all[['user_id', 'category']],on='user_id',how='inner').drop_duplicates().reset_index(drop=True)
ga_with_category
# Out:
#             event_datetime     event  building_type  \
# 0      2020-05-04 00:00:01  building  assembly_shop
# 1      2020-05-05 05:20:15  building  assembly_shop
# 2      2020-05-05 19:24:02  building  assembly_shop
# 3      2020-05-05 20:59:19  building  assembly_shop
# 4      2020-05-06 00:52:56  building  assembly_shop
# ...                    ...       ...            ...
# 135634 2020-05-13 23:56:39  building      spaceport
# 135635 2020-05-18 00:23:28  building      spaceport
# 135636 2020-05-10 23:59:52  building  assembly_shop
# 135637 2020-05-13 08:11:19  building      spaceport
# 135638 2020-05-18 11:11:11  building      spaceport
#
#                                      user_id project_type        date  \
# 0       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04
# 1       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-05
# 2       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-05
# ...

# %% [markdown]
# Теперь представим данные на графике

# %%
plot_func(ga_with_category[['category','user_id']], 'Распределение игроков по способу прохождения'
         , 'Событие', 'Количество игроков', 'nunique','category')

# %% [markdown]
# Около двух третей игроков из тех, что прошли уровень 1 предпочитают победу над оппонентом реализации проекта.

# %% [markdown]
# Рассмотрим также распределение количества времени, которое игроки из каждой категории проводят в игре

# %%
category_gametime = ga_with_category.groupby('user_id').agg({'category':'first'}).merge(gametime['lifetime'],on='user_id')

# %%
x = plot_func(category_gametime, 'Распределение игроков по способу прохождения'
         , 'Событие', 'Время в игре, ч', 'mean','category')

# %% [markdown]
# Больше всего времени в игре проводят игроки, завершающие первый уровень реализацией проекта. Между игроками закончившими первый уровень победой над соперником и еще не закончившими разница не высока.
#
# Рассчитаем среднее количество строений, которое за время игры строит пользователь в каждой стратегии.

# %%
buildings_count = ga_with_category[ga_with_category['event'] == 'building'].groupby('category').agg({'event':'count'})['event']

# %%
number_of_users = ga_with_category.groupby('category').nunique()['user_id']

# %%
round(buildings_count/number_of_users)
# Out:
# category
# finished by defeating     9.0
# finished by project      13.0
# not finished              9.0
# dtype: float64

# %% [markdown]
# Пользователи, которые заканчивают первый уровень проектом строят в среднем на 4 постройки больше пользователей из двух других категорий. Соответственно при модели с показом рекламы на экране постройки, они потенциально принесут больше прибыли.

# %% [markdown]
# * Среди каналов привлечения выделяется Yandex direct, который добавил почти 5000 пользователей, в то время как Youtube channel reklama и Facebook ads привлекли примерно такое же число пользователей суммарно;
#
# * Стоит выделить низкую стоимость привлечения через Youtube channel reklama: в два раза ниже, чем у других источникох, которые примерно равны между собой;
#
# * Среди учтенных пользователей прошли первый уровень 42.9 процента пользователей. Всего 13.7 процентов от всех пользователей выполнили для завершения уровня проект.
#
# * Среднее время проведенное пользователями в игре, за рассмотренный период составляет 253 часа, что соответствует 10,5 суток. Стоит отметить, что среднее время игры для пользователей завершающих первый уровень выполнением проекта выше, чем у пользователей побеждающих врага. Такие пользователи в среднем строят за время прохождения игры больше сооружений 13, против 9.

# %% [markdown]
# ## Расчет бизнес-показателей
# <a id='metrics'></a>

# %% [markdown]
# Для создания пользовательских профилей объединим таблицы событий и источников привлечения

# %%
users_info = ga_with_category.merge(user_source, on = 'user_id')

# %%
users_info
# Out:
#             event_datetime     event  building_type  \
# 0      2020-05-04 00:00:01  building  assembly_shop
# 1      2020-05-05 05:20:15  building  assembly_shop
# 2      2020-05-05 19:24:02  building  assembly_shop
# 3      2020-05-05 20:59:19  building  assembly_shop
# 4      2020-05-06 00:52:56  building  assembly_shop
# ...                    ...       ...            ...
# 135634 2020-05-13 23:56:39  building      spaceport
# 135635 2020-05-18 00:23:28  building      spaceport
# 135636 2020-05-10 23:59:52  building  assembly_shop
# 135637 2020-05-13 08:11:19  building      spaceport
# 135638 2020-05-18 11:11:11  building      spaceport
#
#                                      user_id project_type        date  \
# 0       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04
# 1       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-05
# 2       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-05
# ...

# %% [markdown]
# Создаем таблицу с пользовательскими профилями для расчета бизнес-показателей

# %%
profiles = get_profiles(users_info)
profiles
# Out:
#                                     user_id first_action  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30   2020-05-06
# 1      00151b4f-ba38-44a8-a650-d7cf130a0105   2020-05-06
# 2      001aaea6-3d14-43f1-8ca8-7f48820f17aa   2020-05-05
# 3      001d39dc-366c-4021-9604-6a3b9ff01e25   2020-05-05
# 4      002f508f-67b6-479f-814b-b05f00d4e995   2020-05-05
# ...                                     ...          ...
# 13571  ffef4fed-164c-40e1-bde1-3980f76d0fb5   2020-05-04
# 13572  fffab3da-da0e-4e30-ae62-10d0a2e24a4e   2020-05-04
# 13573  fffb626c-5ab6-47c9-8113-2062a2f18494   2020-05-04
# 13574  ffff194a-56b7-4c12-860d-3485242ae7f5   2020-05-04
# 13575  ffff69cc-fec1-4fd3-9f98-93be1112a6b8   2020-05-08
#
#                         source               category      month
# 0                 facebook_ads           not finished 2020-05-01
# 1                yandex_direct           not finished 2020-05-01
# 2      youtube_channel_reklama           not finished 2020-05-01
# ...

# %% [markdown]
# Изменим дату покупки рекламы, прибавляя к ней один день, для того чтобы она соответствовала дате привлечения новых пользователей.

# %%
ad_costs['day'] = ad_costs['day'] + datetime.timedelta(hours=25)

# %%
ad_costs['day'] = ad_costs['day'].dt.date

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий тимлида (v.2)</b>
#
#
# Кажется уже не актуально
#
# </div>

# %% [markdown]
# ### Расчет CAC, LTV, ROI

# %% [markdown]
# Добавим стоимость одного показа рекламы в таблицу с действиями пользователей. Стоимость одного показа составляет 0.07. Показы осуществляются на странице строительства.

# %%
click_costs = ga_with_category.query('event=="building"')
click_costs['click_cost'] = 0.07
click_costs
# Out:
# /tmp/ipykernel_569/2408379801.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   click_costs['click_cost'] = 0.07
#             event_datetime     event  building_type  \
# 0      2020-05-04 00:00:01  building  assembly_shop
# 1      2020-05-05 05:20:15  building  assembly_shop
# 2      2020-05-05 19:24:02  building  assembly_shop
# 3      2020-05-05 20:59:19  building  assembly_shop
# 4      2020-05-06 00:52:56  building  assembly_shop
# ...                    ...       ...            ...
# 135634 2020-05-13 23:56:39  building      spaceport
# 135635 2020-05-18 00:23:28  building      spaceport
# 135636 2020-05-10 23:59:52  building  assembly_shop
# 135637 2020-05-13 08:11:19  building      spaceport
# ...

# %% [markdown]
# Добавим в таблицу событий стоимость одного клика

# %%
ga_with_category = ga_with_category.merge(click_costs[['event_datetime','click_cost','user_id']]
                                  , on=['event_datetime','user_id'], how='left')
ga_with_category
# Out:
#             event_datetime     event  building_type  \
# 0      2020-05-04 00:00:01  building  assembly_shop
# 1      2020-05-05 05:20:15  building  assembly_shop
# 2      2020-05-05 19:24:02  building  assembly_shop
# 3      2020-05-05 20:59:19  building  assembly_shop
# 4      2020-05-06 00:52:56  building  assembly_shop
# ...                    ...       ...            ...
# 135634 2020-05-13 23:56:39  building      spaceport
# 135635 2020-05-18 00:23:28  building      spaceport
# 135636 2020-05-10 23:59:52  building  assembly_shop
# 135637 2020-05-13 08:11:19  building      spaceport
# 135638 2020-05-18 11:11:11  building      spaceport
#
#                                      user_id project_type        date  \
# 0       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04
# 1       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-05
# 2       55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-05
# ...

# %% [markdown]
# Произведем расчеты бизнес показателей для всех пользователей

# %% [markdown]
# Добавим в таблицу событий рекламные источники, а также информацию о дате первого действия для пользователей

# %%
ga_with_category = ga_with_category.merge(user_source,on='user_id')
ga_with_category = ga_with_category.merge(profiles[['user_id','first_action']],on='user_id',how='left')
ga_with_category['first_action'] = pd.to_datetime(ga_with_category['first_action'])
ga_with_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135639 entries, 0 to 135638
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   event_datetime  135639 non-null  datetime64[ns]
#  1   event           135639 non-null  object
#  2   building_type   127956 non-null  object
#  3   user_id         135639 non-null  object
#  4   project_type    1866 non-null    object
#  5   date            135639 non-null  object
#  6   category        135639 non-null  object
#  7   click_cost      127956 non-null  float64
#  8   source          135639 non-null  object
#  9   first_action    135639 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(7)
# memory usage: 11.4+ MB

# %% [markdown]
# Определим количество привлеченных по каждому каналу пользователей в каждый день

# %%
unique_users = (ga_with_category.groupby(['first_action', 'source'])
        .agg({'user_id': 'nunique'})
         # столбец с числом пользователей назовём unique_users
        .rename(columns={'user_id': 'unique_users'})
        .reset_index() 
               )
unique_users
# Out:
#    first_action                   source  unique_users
# 0    2020-05-04             facebook_ads          1184
# 1    2020-05-04    instagram_new_adverts          1452
# 2    2020-05-04            yandex_direct          2078
# 3    2020-05-04  youtube_channel_reklama          1146
# 4    2020-05-05             facebook_ads           694
# 5    2020-05-05    instagram_new_adverts           796
# 6    2020-05-05            yandex_direct          1208
# 7    2020-05-05  youtube_channel_reklama           663
# 8    2020-05-06             facebook_ads           345
# 9    2020-05-06    instagram_new_adverts           472
# 10   2020-05-06            yandex_direct           664
# 11   2020-05-06  youtube_channel_reklama           366
# 12   2020-05-07             facebook_ads           224
# 13   2020-05-07    instagram_new_adverts           270
# 14   2020-05-07            yandex_direct           395
# 15   2020-05-07  youtube_channel_reklama           220
# ...

# %% [markdown]
# Внесем информацию о количестве привлеченных пользователей из рекламных каналов, а также стоимость рекламы, в таблицу событий для расчета CAC

# %%
# Преобразуем тип данных в столбце 'first_action' и изменим его название на date
unique_users['first_action'] = pd.to_datetime(unique_users['first_action'])
unique_users = unique_users.rename(columns={'first_action':'date'})

# Проведем аналогичные манипуляции с данными для столбца day таблицы ad_costs
ad_costs = ad_costs.rename(columns={'day':'date'})
ad_costs['date'] = pd.to_datetime(ad_costs['date'])

# Преобразуем столбец date таблицы ga_with_category к типу datetime. Проведем объединение с таблицами
# unique_users и ad_costs
ga_with_category['date'] = pd.to_datetime(ga_with_category['date'])
ga_with_category = ga_with_category.merge(unique_users, on=['date','source'],how='left')
ga_with_category = ga_with_category.merge(ad_costs,on=['date','source'],how='left')
ga_with_category
# Out:
#             event_datetime     event  building_type  \
# 0      2020-05-04 00:00:01  building  assembly_shop
# 1      2020-05-05 05:20:15  building  assembly_shop
# 2      2020-05-05 19:24:02  building  assembly_shop
# 3      2020-05-05 20:59:19  building  assembly_shop
# 4      2020-05-06 00:52:56  building  assembly_shop
# ...                    ...       ...            ...
# 135634 2020-05-13 23:56:39  building      spaceport
# 135635 2020-05-18 00:23:28  building      spaceport
# 135636 2020-05-10 23:59:52  building  assembly_shop
# 135637 2020-05-13 08:11:19  building      spaceport
# 135638 2020-05-18 11:11:11  building      spaceport
#
#                                      user_id project_type       date  \
# 0       55e92310-cb8e-4754-b622-597e124b03de          NaN 2020-05-04
# 1       55e92310-cb8e-4754-b622-597e124b03de          NaN 2020-05-05
# 2       55e92310-cb8e-4754-b622-597e124b03de          NaN 2020-05-05
# ...

# %% [markdown]
# Рассчитаем стоимость привлечения одного пользователя и добавим ее в таблицу.

# %%
ga_with_category['acquisition_cost'] = ga_with_category['cost']/ga_with_category['unique_users']

# %% [markdown]
# Внесем в таблицу профилей информацию о совершении первого события.

# %%
profiles['first_action'] = pd.to_datetime(profiles['first_action'])

# %% [markdown]
# ### Расчет метрик общей группы пользователей

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    ga_with_category,
    dimensions = []
)

# %% [markdown]
# Визуализируем показатели

# %%
report = ltv_history.drop(columns=['cohort_size'])
vis_ltv(report.T, 'LTV по датам привлечения')

# %% [markdown]
# LTV пользователей привлеченных в два первых дня выше, чем средний. Причем наблюдается снижение пользовательской активности игроков с приближением к последней дате рекламы.

# %% [markdown]
# Рассмотрим CAC и ROMI

# %%
roi_history['cac'].plot(grid=True, figsize=(10, 5), color='aquamarine', linewidth=3, marker='D'
                       , markerfacecolor = 'violet', markersize=15, markeredgecolor='black')
plt.title('CAC по датам привлечения')
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.show()

# %% [markdown]
# Очень близкие значения стоимости привлечения пользователей

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI общей группы пользователей')

# %% [markdown]
# Реклама окупается на девятый день

# %% [markdown]
# ### Расчет метрик в разрезе каналов привлечения

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    ga_with_category,
    dimensions = ['source']
)

# %%
report = ltv.drop(columns=['cohort_size'])
vis_ltv(report.T, 'LTV по каналам привлечения')

# %% [markdown]
# Видим, что пользователи привлеченные из всех источников генерируют одинаковую прибыль

# %%
# строим график истории изменений CAC
colors = ['aquamarine', 'violet', 'wheat', 'cornflowerblue']
roi_history.pivot_table(
    index='first_action', columns='source', values='cac', aggfunc='mean'
).plot(figsize=(10, 5), color=colors, linewidth = 2)

plt.ylabel('CAC, $')
plt.grid(linestyle=':', color='k')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
sns.despine()
plt.tick_params(direction='inout')
plt.show()

# %% [markdown]
# Выделяется Facebook ads с высокой стоимостью привлечения, а также Instagram new adverts с величиной выше среднего.

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI по каналам привлечения')

# %% [markdown]
# Реклама из facebook_ads не окупается, из instagram ROI немного выше 1. Выделяется реклама из Youtube с возвратом 1.6, Яндекс директ демонстрирует также хороший уровень в 1.4.

# %% [markdown]
# ### Расчет метрик для категорий пользователей по способу прохождения уровня

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    ga_with_category,
    dimensions = ['category']
)

# %%
report = ltv.drop(columns=['cohort_size'])
vis_ltv(report.T, 'LTV по способу прохождения уровня')

# %% [markdown]
# Пользователи завершающие первый уровень выполнением проекта наиболее выгодны.

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI по способу прохождения уровня')

# %% [markdown]
# Пользователи, которые завершают игру выполнением проекта приносят прибыль уже на 7 день.

# %% [markdown]
# ### Сценарий с показом рекламы при завершении уровня

# %% [markdown]
# Сценарий предполагает показ рекламы после завершения первого уровня.
#
# Подготовим данные.

# %%
case_1 = ga_with_category
case_1.drop(columns='click_cost')
case_1['click_cost'] = 0
case_1.loc[(case_1.event == 'finished_stage_1'), 'click_cost'] = 0.07

# %% [markdown]
# Посчитаем ROMI

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_1,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы после окончания уровня')

# %% [markdown]
# Данная модель убыточна

# %% [markdown]
# ### Сценарий с показом рекламы при строительстве одного из типов зданий

# %% [markdown]
# Считаем ROMI для сборочного цеха

# %%
case_2 = ga_with_category
case_2.drop(columns='click_cost')
case_2['click_cost'] = 0
case_2.loc[(case_2.building_type == 'assembly_shop'), 'click_cost'] = 0.07

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_2,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы после строительства сборочного цеха')

# %% [markdown]
# Сценарий с выбором сборочного цеха, как объекта для строительства рекламы - убыточен

# %% [markdown]
# Считаем сценарий для космопорта

# %%
case_3 = ga_with_category
case_3.drop(columns='click_cost')
case_3['click_cost'] = 0
case_3.loc[(case_3.building_type == 'spaceport'), 'click_cost'] = 0.07

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_3,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы после строительства космопорта')

# %% [markdown]
# Результаты лучше, но окупаемости не видно

# %% [markdown]
# ### Сценарий с показом рекламы со второго дня

# %%
case_4 = ga_with_category
case_4.drop(columns='click_cost')
case_4['click_cost'] = 0
case_4.loc[(case_4.date > datetime.datetime.strptime('2020-05-04', "%Y-%m-%d")), 'click_cost'] = 0.07

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_4,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы со второго дня в игре')

# %% [markdown]
# Реклама окупится, проверим, как повлияет исключение более поздних дат

# %%
case_5 = ga_with_category
case_5.drop(columns='click_cost')
case_5['click_cost'] = 0
case_5.loc[(case_5.date > datetime.datetime.strptime('2020-05-05', "%Y-%m-%d")), 'click_cost'] = 0.07

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_5,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы с третьего дня в игре')

# %% [markdown]
# Если рекламу включать на третий день игры, то это еще будет выгодно. Но более позднее начало показа будет убыточно.

# %% [markdown]
# ### Сценарий с показом рекламы по прошествии определенного количества построек

# %% [markdown]
# Добавим столбец с порядковым номером действия игрока

# %%
case_6 = ga_with_category
case_6.drop(columns='click_cost')
case_6['click_cost'] = 0
case_6['RN'] = case_6.sort_values(by='event_datetime').groupby(['user_id']).cumcount() + 1
case_6.loc[(case_6.RN > 3), 'click_cost'] = 0.07

# %% [markdown]
# Просчитаем ROMI модели, при которой показ рекламы начнется после трех действий

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_6,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы после постройки трех сооружений')

# %% [markdown]
# Такая модель невыгодна

# %%
case_7 = ga_with_category
case_7.drop(columns='click_cost')
case_7['click_cost'] = 0
case_7['RN'] = case_7.sort_values(by='event_datetime').groupby(['user_id']).cumcount() + 1 
case_7.loc[(case_7.RN > 2), 'click_cost'] = 0.07

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_7,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы после постройки двух сооружений')

# %% [markdown]
# Здесь ROMI выходит ровно в точку безубыточности

# %%
case_8 = ga_with_category
case_8.drop(columns='click_cost')
case_8['click_cost'] = 0
case_8['RN'] = case_8.sort_values(by='event_datetime').groupby(['user_id']).cumcount() + 1 
case_8.loc[(case_8.RN > 1), 'click_cost'] = 0.07

# %%
raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles,
    case_8,
    dimensions = []
)

# %%
report = roi.drop(columns=['cohort_size','cac'])
vis_roi(report, 'ROMI модели с показом рекламы после постройки одного сооружения')

# %% [markdown]
# Включение рекламы с экрана выбора второй постройки является рентабельным

# %% [markdown]
# * Чем позднее дата привлечения в рекламной компании, тем менее прибыльными оказывались клиенты. Графики LTV наглядно показывают снижение параметра от пользователей первой даты привлечения к последней;
#
# * Ценность пользователей привлеченных из разных источников рекламного трафика достигает одинаковых величин во всех четырех случаях. Однако, низкая стоимость привлечения в каналах Yandex direct и Youtube channel reklama делают их высокодоходными с ROMI 1.4 и 1.6 соответственно. При этом реклама из Facebook ads оказалась убыточной;
#
# * Пользователи, которые заканчивают первый уровень выполнением проекта имеют LTV почти на 30 % больше, чем пользователи побеждающие оппонента, что делает их стратегию наиболее выгодной для приложения.
#
# * Моделями способными генерировать прибыль показали себя: включение рекламы со второго действия, показ рекламы со второго или с третьего дня входа пользователя в приложение

# %% [markdown]
# ## Проверка гипотез
# <a id="hyp"></a>

# %%
ga_with_category.loc[(ga_with_category.event == 'building'), 'click_cost'] = 0.07

# %% [markdown]
# ### Гипотеза о различии времени прохождения первого уровня

# %% [markdown]
# Сформулируем гипотезы
# Нулева гипотезая (H0): Среднее время прохождения первого уровня, для пользователей выполняющих проект и побеждающих соперника, одинаково
#
# Альтернативная гипотеза(H1): Между средним временем прохождения первого уровня, для пользователей выполняющих проект и побеждающих соперника, имеет статистически значимое различие
#
# Уровень значимости = 0.05

# %%
stat_test = ga_with_category.merge(gametime['lifetime'],on='user_id',how='left')
stat_test['lifetime'] = stat_test['lifetime'].astype('int')

# %%
st.ttest_ind(stat_test.query('category == "finished by project"')['lifetime'], 
                        stat_test.query('category == "finished by defeating"')['lifetime'],equal_var=False)[1]
# Out:
# 0.0

# %% [markdown]
# Среднее время прохождения первого уровня различается

# %% [markdown]
# ### Гипотеза о различии доли прибыли, приносимой игроками из разных каналов

# %% [markdown]
# Сформулируем гипотезы
# Нулева гипотезая (H0): Доля от прибыли игроков привлеченных из канала Yandex direct равна доле от прибыли игроков из канала Youtube channel reklama для категории игроков, завершивших уровень выполнением проекта
#
# Альтернативная гипотеза(H1): Между долями от прибыли игроков из каналов Yandex direct и Youtube channel reklama для категории игроков, завершивших первый уровень выполнением проекта, существует статистически значимое различие
#
# Уровень значимости = 0.05

# %%
alpha = .05 # критический уровень статистической значимости
successes1 = ga_with_category.query(
    ('source == "yandex_direct" and category == "finished by project"'))['click_cost'].sum()
successes2 = ga_with_category.query(
    ('source == "youtube_channel_reklama" and category == "finished by project"'))['click_cost'].sum()
trials = ga_with_category.query('category == "finished by project"')['click_cost'].sum()

#доля успехов в комбинированном датасете
p = (successes1 + successes2) / trials
     
#разница долей в датасетах
difference = successes1/trials - successes2/trials
     
z_value = difference/mt.sqrt(p*(1-p)*(1/trials + 1/trials))

distr = st.norm(0,1)
     
p_value = (1 - distr.cdf(abs(z_value))) * 2

if p_value < alpha: 
    print('p-значение:', p_value), print("Между выборками существует статистически значимая разница")
else: 
    print('p-значение:', p_value), print("Нет статистически значимой разницы между выборками")
# Out:
# p-значение: 1.5543122344752192e-15
# Между выборками существует статистически значимая разница

# %% [markdown]
# * Среднее время игры для пользователей выбирающих разную стратегию прохождения первого уровня является различным
#
# * Пользователи привлеченные из Yandex direct и Youtube channel reklama имеют различную долю от прибыли принесенной игроками из категории прошедших первый уровень выполнением проекта

# %% [markdown]
# ## Вывод

# %% [markdown]
# 1. Наиболее рентабельной моделью монетизации является включение показа рекламы со второго дня. Также окупится модель включения рекламы со второго действия или с третьего дня. Показ рекламы со второго дня позволит пользователю вникнуть в механику и освоиться без отвлекающих факторов;
#
# 2. Гипотеза о разнице среднего времени, проводимого в игре пользователями, которые разными способами заканчивают первый уровень подтвердилась. Между тем, гипотеза о том что доли прибыли пользователей из каналов Yandex direct и Youtube channel reklama в категории, выполнивших проект, оказалась отвергнута;
#
# 3. Самыми прибыльными пользователями являются, придерживающиеся стратегии выполнения проекта. Необходимо поощрять игроков, которые выбирают данную стратегию, повышая их лояльность. Для увеличения ROMI необходимо отказаться от явно неэффективного канала Facebook ads, и пересмотреть затраты на привлечение через Instagram new adverts.
